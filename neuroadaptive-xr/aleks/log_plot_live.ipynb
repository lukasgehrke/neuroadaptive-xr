# %%
import os
import glob
import time
from IPython import display

import matplotlib.pyplot as plt
import pandas as pd

from log_plotting import plot_q_learning_separate


def get_latest_log_file(path):
    list_of_files = glob.glob(os.path.join(path, 'rl', 'logs', '*'))
    if not list_of_files:
        raise FileNotFoundError("No log files found in the specified directory.")
    return max(list_of_files, key=os.path.getctime)

def read_log_file(filename):
    try:
        return pd.read_csv(filename, header=0)
    except PermissionError as e:
        print(f"PermissionError: {e}")
        return None

def clear_axes(axes, max_steps):
    for axis in axes:
        axis.clear()
        axis.set_xlim(0, max_steps)
        axis.set_ylim(-1.0, 1.5)

def live_plot(log_filename, fig, ax, max_steps):
    while True:
        df = read_log_file(log_filename)
        if df is None:
            break
        
        df_plot = df
        clear_axes(ax, max_steps)
        plot_q_learning_separate(df_plot, ax)
        
        display.clear_output(wait=True)
        display.display(fig)
        plt.close(fig)
        
        time.sleep(0.1)
        
        if len(df) >= max_steps:
            break

# %% [markdown]
# # Static plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
current_path = os.getcwd()
log_filename = get_latest_log_file(current_path)
max_steps = 25

title = 'agent' # E.G.

with sns.plotting_context('paper', font_scale = 1.2):

    fig, ax = plt.subplots(2, 1, figsize=(5,4))
    # fig, ax = plt.subplots(2, 1)


    df_plot = read_log_file(log_filename)

    clear_axes(ax, max_steps)
    plot_q_learning_separate(df_plot, ax)


    fig.patch.set_alpha(1)
    plt.tight_layout()
    ax[0].set_ylim(-1.2, 1.2)
    ax[1].set_ylim(-0.2, 1.2)

    sns.despine() #bottom=True, left=True    

    # fig.savefig(title + '.eps', format='eps', transparent=True, bbox_inches='tight', dpi=300)
    # fig.savefig(title + '.svg', format='svg', transparent=True, bbox_inches='tight', dpi=300)
    # fig.savefig(title + '.png', format='png', transparent=True, bbox_inches='tight', dpi=300)

# %% [markdown]
# # Live plot

# %%
# This will start live plotting the newest log file

current_path = os.getcwd()
log_filename = get_latest_log_file(current_path)
max_steps = 35

fig, ax = plt.subplots(2, 1, figsize=(12, 8))
live_plot(log_filename, fig, ax, max_steps)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 8
#       5 max_steps = 35
#       7 fig, ax = plt.subplots(2, 1, figsize=(12, 8))
# ----> 8 live_plot(log_filename, fig, ax, max_steps)
#
# Cell In[1], line 43, in live_plot(log_filename, fig, ax, max_steps)
#      41 df_plot = df
#      42 clear_axes(ax, max_steps)
# ---> 43 plot_q_learning_separate(df_plot, ax)
#      45 display.clear_output(wait=True)
#      46 display.display(fig)
#
# File ~/other/git/2022-CHI-neuroadaptive-haptics/neuroadaptive-xr/aleks/log_plotting.py:51, in plot_q_learning_separate(df, ax)
#      49 df_plot_q_values = df.pivot(index='t', columns='action', values='new_Q_value')
#      50 plot_q_values(df_plot_q_values, ax1, initial_q_value)
# ---> 51 plot_additional_metrics(df, ax2)
#      53 # Pre-emptive exploration
#      54 # ax1.axvline(x=25, color='lightgray', linestyle='--', zorder=0)
#      55 # ax2.axvline(x=25, color='lightgray', linestyle='--', zorder=0)
#      57 handles1, labels1 = ax1.get_legend_handles_labels()
#
# File ~/other/git/2022-CHI-neuroadaptive-haptics/neuroadaptive-xr/aleks/log_plotting.py:26, in plot_additional_metrics(df, ax)
#      25 def plot_additional_metrics(df, ax):
# ---> 26     df.plot('t', ['reward', 'alpha', 'epsilon'],
#      27             # Re-enable when plotting not_separate
#      28             #  color=['lightblue', 'lightgreen', 'lightpink'],
#      29              ax=ax, zorder=0, linewidth=1)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:700, in MPLPlot._compute_plot_data(self)
#     697 if is_empty:
#     698     raise TypeError("no numeric data to plot")
# --> 700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/core/apply.py:1068, in FrameApply.apply_standard(self)
#    1065     results, res_index = self.apply_series_numba()
#    1067 # wrap results
# -> 1068 return self.wrap_results(results, res_index)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/core/apply.py:1107, in FrameApply.wrap_results(self, results, res_index)
#    1105 # see if we can infer the results
#    1106 if len(results) > 0 and 0 in results and is_sequence(results[0]):
# -> 1107     return self.wrap_results_for_axis(results, res_index)
#    1109 # dict of scalars
#    1110
#    1111 # the default dtype of an empty Series is `object`, but this
#    1112 # code can be hit by df.mean() where the result should have dtype
#    1113 # float64 even if it's an empty Series.
#    1114 constructor_sliced = self.obj._constructor_sliced
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/core/apply.py:1219, in FrameRowApply.wrap_results_for_axis(self, results, res_index)
#    1216     return res
#    1218 try:
# -> 1219     result = self.obj._constructor(data=results)
#    1220 except ValueError as err:
#    1221     if "All arrays must be of the same length" in str(err):
#    1222         # e.g. result = [[2, 3], [1.5], ['foo', 'bar']]
#    1223         #  see test_agg_listlike_result GH#29587
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/core/internals/construction.py:480, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     478 else:
#     479     keys = list(data.keys())
# --> 480     columns = Index(keys) if keys else default_index(0)
#     481     arrays = [com.maybe_iterable_to_list(data[k]) for k in keys]
#     483 if copy:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/core/indexes/base.py:574, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     571     raise
#     572 arr = ensure_wrapped_if_datetimelike(arr)
# --> 574 klass = cls._dtype_to_subclass(arr.dtype)
#     576 arr = klass._ensure_array(arr, arr.dtype, copy=False)
#     577 result = klass._simple_new(arr, name, refs=refs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lukas-nah/lib/python3.12/site-packages/pandas/core/indexes/base.py:609, in Index._dtype_to_subclass(cls, dtype)
#     606         data = data.copy()
#     607     return data
# --> 609 @final
#     610 @classmethod
#     611 def _dtype_to_subclass(cls, dtype: DtypeObj):
#     612     # Delay import for perf. https://github.com/pandas-dev/pandas/pull/31423
#     614     if isinstance(dtype, ExtensionDtype):
#     615         return dtype.index_class
#
# KeyboardInterrupt:
